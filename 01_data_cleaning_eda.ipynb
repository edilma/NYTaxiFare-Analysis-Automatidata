# %% [markdown]
# ## Data visualizations and EDA

# %%
#  Imports 
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns

# %%
#Load the dataset
taxi_data = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv', index_col=0)

# %%
#Data exploration 
taxi_data.head()
# Out:
#            VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 24870114          2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 35634249          1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 38942136          2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 30841670          2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#            passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 24870114                 6           3.34           1                  N
# 35634249                 1           1.80           1                  N
# 106203690                1           1.00           1                  N
# 38942136                 1           3.70           1                  N
# 30841670                 1           4.37           1                  N
#
#            PULocationID  DOLocationID  payment_type  fare_amount  extra  \
# ...

# %%
taxi_data.size
# Out:
# 385883

# %%
taxi_data.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  22699.000000     22699.000000   22699.000000  22699.000000
# mean       1.556236         1.642319       2.913313      1.043394
# std        0.496838         1.285231       3.653171      0.708391
# min        1.000000         0.000000       0.000000      1.000000
# 25%        1.000000         1.000000       0.990000      1.000000
# 50%        2.000000         1.000000       1.610000      1.000000
# 75%        2.000000         2.000000       3.060000      1.000000
# max        2.000000         6.000000      33.960000     99.000000
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean     162.412353    161.527997      1.336887     13.026629      0.333275
# std       66.633373     70.139691      0.496211     13.243791      0.463097
# ...

# %%
taxi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22699 entries, 24870114 to 17208911
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               22699 non-null  int64
#  1   tpep_pickup_datetime   22699 non-null  object
#  2   tpep_dropoff_datetime  22699 non-null  object
#  3   passenger_count        22699 non-null  int64
#  4   trip_distance          22699 non-null  float64
#  5   RatecodeID             22699 non-null  int64
#  6   store_and_fwd_flag     22699 non-null  object
#  7   PULocationID           22699 non-null  int64
#  8   DOLocationID           22699 non-null  int64
#  9   payment_type           22699 non-null  int64
#  10  fare_amount            22699 non-null  float64
#  11  extra                  22699 non-null  float64
#  12  mta_tax                22699 non-null  float64
#  13  tip_amount             22699 non-null  float64
# ...

# %% [markdown]
# ## Visualization of the data
# ### Trip Distance

# %%
# boxpot of trip distance
plt.figure(figsize=(10, 6)) 
sns.boxplot(x=taxi_data['trip_distance'])
plt.title('Boxplot of Trip Distance')
# Out:
# Text(0.5, 1.0, 'Boxplot of Trip Distance')

# %%
#histogram of trip distance
plt.figure(figsize=(10, 6))
sns.histplot(taxi_data['trip_distance'], bins=50)
plt.title('Histogram of Trip Distance')
# Out:
# Text(0.5, 1.0, 'Histogram of Trip Distance')

# %% [markdown]
# The majority of the trips were of less than 2 miles

# %% [markdown]
# ### Total Amount

# %%
# boxpot of fare amount 
plt.figure(figsize=(10, 6)) 
sns.boxplot(x=taxi_data['total_amount'])
plt.title('Boxplot of Total Amount')
# Out:
# Text(0.5, 1.0, 'Boxplot of Total Amount')

# %%
taxi_data['total_amount'].describe()
# Out:
# count    22699.000000
# mean        16.310502
# std         16.097295
# min       -120.300000
# 25%          8.750000
# 50%         11.800000
# 75%         17.800000
# max       1200.290000
# Name: total_amount, dtype: float64

# %%
#histogram of Total Amount
plt.figure(figsize=(10, 6))
sns.histplot(taxi_data['total_amount'], bins=range(-10,101,5))
plt.title('Total Amount Histogram')
# Out:
# Text(0.5, 1.0, 'Total Amount Histogram')

# %% [markdown]
# Most of the total amount are between $5 and $15

# %% [markdown]
# ### Tip Amount

# %%
# boxpot of tip amount 
plt.figure(figsize=(10, 6)) 
sns.boxplot(x=taxi_data['tip_amount'])
plt.title('Boxplot of Tip Amount')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tip Amount')

# %%
taxi_data['tip_amount'].describe()
# Out:
# count    22699.000000
# mean         1.835781
# std          2.800626
# min          0.000000
# 25%          0.000000
# 50%          1.350000
# 75%          2.450000
# max        200.000000
# Name: tip_amount, dtype: float64

# %%
#histogram of Tip Amount
plt.figure(figsize=(10, 6))
sns.histplot(taxi_data['tip_amount'], bins=range(0,21,1))
plt.title('Total Tip Amount Histogram')
plt.xlabel('Tip Amount')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Most of the tips are about $0-$3

# %% [markdown]
# ### Tip amount by vendor

# %%
#tip_by_vendor = [taxi_data['tip_amount', 'VendorID']]
taxi_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22699 entries, 24870114 to 17208911
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               22699 non-null  int64
#  1   tpep_pickup_datetime   22699 non-null  object
#  2   tpep_dropoff_datetime  22699 non-null  object
#  3   passenger_count        22699 non-null  int64
#  4   trip_distance          22699 non-null  float64
#  5   RatecodeID             22699 non-null  int64
#  6   store_and_fwd_flag     22699 non-null  object
#  7   PULocationID           22699 non-null  int64
#  8   DOLocationID           22699 non-null  int64
#  9   payment_type           22699 non-null  int64
#  10  fare_amount            22699 non-null  float64
#  11  extra                  22699 non-null  float64
#  12  mta_tax                22699 non-null  float64
#  13  tip_amount             22699 non-null  float64
# ...

# %%
taxi_data['VendorID'].value_counts()
taxi_data['tip_amount'].describe()
# Out:
# count    22699.000000
# mean         1.835781
# std          2.800626
# min          0.000000
# 25%          0.000000
# 50%          1.350000
# 75%          2.450000
# max        200.000000
# Name: tip_amount, dtype: float64

# %% [markdown]
# #there are only 2 vendors.

# %%
#histogram of Tip Amount
plt.figure(figsize=(10, 6))
sns.histplot(
    data= taxi_data, 
    x='tip_amount',
    bins=range(0,15,1),
    hue='VendorID',
    multiple='stack',
    palette='Set1'
    )
plt.title('Tip Amount by Vendor ID Histogram')
plt.xlabel('Tip Amount')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The amount of tip by vendor has similar distributions. The vendor #2 has more trips .
# I made the graph for tips up to $15 because the average tip is 1.8 and the 75% is 2.45.  I am including more of the tips received.
# Now I will analize the distribution of the big tips ( over $10)

# %%
tips_over_10 = taxi_data[taxi_data['tip_amount'] > 10]
tips_over_10['VendorID'].value_counts()
# Out:
# VendorID
# 2    275
# 1    171
# Name: count, dtype: int64

# %%
#histogram of Tips over $10
plt.figure(figsize=(10, 6))
sns.histplot(
    data= tips_over_10, 
    x='tip_amount',
    bins=range(10,30,1),
    hue='VendorID',
    multiple='stack',
    palette='Set1'
    )
plt.title('Tips over $10 by Vendor ID Histogram')
plt.xlabel('Tip Amount')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The vendor #2 has a higher tip amount.  This is consistent also in the average tips.

# %% [markdown]
# ## Mean tips by passenger count

# %%
passenger_count = taxi_data['passenger_count'].value_counts(normalize=True)*100
passenger_count
# Out:
# passenger_count
# 1    71.003128
# 2    14.560113
# 5     5.035464
# 3     4.198423
# 6     3.052998
# 4     2.004494
# 0     0.145381
# Name: proportion, dtype: float64

# %% [markdown]
# 71% of the trips are taken by single passengers and 86% for 2 passengers or less.  We also have a 0.14% of trips with no passengers.  This could be trips to do errans.  No explanations were given.

# %%
mean_tip_by_passenger_count = taxi_data.groupby('passenger_count')['tip_amount'].mean().reset_index()
mean_tip_by_passenger_count
# Out:
#    passenger_count  tip_amount
# 0                0    2.135758
# 1                1    1.848920
# 2                2    1.856378
# 3                3    1.716768
# 4                4    1.530264
# 5                5    1.873185
# 6                6    1.720260

# %%
overall_mean = taxi_data['tip_amount'].mean()

# bar plot of mean tip by passenger count
plt.figure(figsize=(10, 6)) 
sns.barplot(data=mean_tip_by_passenger_count ,  x='passenger_count', y='tip_amount')
plt.axhline(overall_mean, color='red', linestyle='--', label=f'Overall Mean: {overall_mean:.2f}')
plt.legend()
plt.title('Mean Tip Amount by Passenger Count')
plt.xlabel('Passenger Count')
plt.ylabel('Mean Tip Amount')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# If we ignore trips with 0 passengers (which may be data errors), the mean tip amount remains relatively consistent across different passenger counts. This suggests that the number of passengers does not significantly affect the average tip given.

# %% [markdown]
# ## Analysis of rides based on time

# %%
#convert datetime columns to datetime objects
taxi_data['tpep_pickup_datetime'] = pd.to_datetime(taxi_data['tpep_pickup_datetime'])
taxi_data['tpep_dropoff_datetime'] = pd.to_datetime(taxi_data['tpep_dropoff_datetime'])

# %%
# Create a month column
taxi_data['month'] = taxi_data['tpep_pickup_datetime'].dt.month_name()
# Create a day column
taxi_data['day'] = taxi_data['tpep_pickup_datetime'].dt.day_name()

# %%
#ride counts by month
ride_counts_by_month = taxi_data['month'].value_counts().sort_index()
ride_counts_by_month
# Out:
# month
# April        2019
# August       1724
# December     1863
# February     1769
# January      1997
# July         1697
# June         1964
# March        2049
# May          2013
# November     1843
# October      2027
# September    1734
# Name: count, dtype: int64

# %%
# Categorical month order
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
               'July', 'August', 'September', 'October', 'November', 'December']
ride_counts_by_month = ride_counts_by_month.reindex(month_order)
ride_counts_by_month
# Out:
# month
# January      1997
# February     1769
# March        2049
# April        2019
# May          2013
# June         1964
# July         1697
# August       1724
# September    1734
# October      2027
# November     1843
# December     1863
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    x=ride_counts_by_month.index,
    y=ride_counts_by_month.values,
    hue=ride_counts_by_month.index,  
    palette='Set2',
    legend=False  
    )
plt.title('Number of Rides by Month')
plt.xlabel('Month')
plt.ylabel('Ride Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Ride counts dip during the summer months (June to August), while the rest of the year shows relatively consistent ride volumes.

# %%
#ride counts by day 
ride_counts_by_day = taxi_data['day'].value_counts().sort_index()
# Categorical day order
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
ride_counts_by_day = ride_counts_by_day.reindex(day_order)
ride_counts_by_day
# Out:
# day
# Monday       2931
# Tuesday      3198
# Wednesday    3390
# Thursday     3402
# Friday       3413
# Saturday     3367
# Sunday       2998
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    x=ride_counts_by_day.index,
    y=ride_counts_by_day.values,
    hue=ride_counts_by_day.index,  
    palette='tab10',
    legend=False  
    )
plt.title('Number of Rides by Day')
plt.xlabel('Day of the Week')
plt.ylabel('Ride Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Sunday and Monday has the least amount of rides while Wednesday to Saturday had the highest and similar number of rides.

# %% [markdown]
# ## Analysis of rides by revenue

# %%
#Revenue by month
revenue_by_month = taxi_data.groupby('month')['total_amount'].sum().reindex(month_order)
revenue_by_month
# Out:
# month
# January      31735.25
# February     28937.89
# March        33085.89
# April        32012.54
# May          33828.58
# June         32920.52
# July         26617.64
# August       27759.56
# September    28206.38
# October      33065.83
# November     30800.44
# December     31261.57
# Name: total_amount, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    x=revenue_by_month.index,
    y=revenue_by_month.values,
    hue=revenue_by_month.index,  
    palette='Set2',
    legend=False  
    )
plt.title('Total Revenue by Month')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Monthly revenue follows the pattern of the rides by month

# %%
#Total revenue by day
revenue_by_day = taxi_data.groupby('day')['total_amount'].sum().reindex(day_order)
revenue_by_day
# Out:
# day
# Monday       49574.37
# Tuesday      52527.14
# Wednesday    55310.47
# Thursday     57181.91
# Friday       55818.74
# Saturday     51195.40
# Sunday       48624.06
# Name: total_amount, dtype: float64

# %%
#plot total revenue by day
plt.figure(figsize=(12, 6)) 
sns.barplot(
    x=revenue_by_day.index,
    y=revenue_by_day.values,
    hue=revenue_by_day.index,  
    palette='tab10',
    legend=False  
    )
plt.title('Total Revenue by Day of the Week')
plt.xlabel('Day')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The revenue by day also follows the pattern of the rides by day.  Tuesday to Friday are the days that more money is collected

# %% [markdown]
# ## Analysis by distance

# %%
#Unique dropoff locations
unique_dropoff_locations = taxi_data['DOLocationID'].nunique()
print(f"Number of unique dropoff locations: {unique_dropoff_locations}")
# Out:
# Number of unique dropoff locations: 216

# %%
#Mean distance by dropoff location
mean_distance_by_dropoff = (
        taxi_data
        .groupby('DOLocationID')['trip_distance']
        .mean()
        .reset_index()
        .sort_values(by='trip_distance',  ascending=True))
mean_distance_by_dropoff
# Out:
#      DOLocationID  trip_distance
# 164           207       1.200000
# 154           193       1.390556
# 192           237       1.555494
# 189           234       1.727806
# 109           137       1.818852
# ..            ...            ...
# 40             51      17.310000
# 5              11      17.945000
# 167           210      20.500000
# 21             29      21.650000
# 16             23      24.275000
#
# [216 rows x 2 columns]

# %%
# Reset index so that DOLocationID becomes a column
mean_distance_by_dropoff = mean_distance_by_dropoff.reset_index()

# Sort by trip_distance
distance_by_dropoff = mean_distance_by_dropoff.sort_values(by='trip_distance', ascending=True)

# Now plot with explicit column references
plt.figure(figsize=(14, 6))
sns.barplot(
    data=mean_distance_by_dropoff,
    x='DOLocationID',
    y='trip_distance',
    order=mean_distance_by_dropoff['DOLocationID']
)
plt.title('Mean Trip Distance by Drop-off Location', fontsize=16)
plt.xlabel('Dropoff Location ID')
plt.ylabel('Mean Trip Distance (miles)')
plt.xticks(rotation=90, fontsize=6)
plt.tight_layout()
plt.show()

# %% [markdown]
# The shape of the graph shows a smooth, upward-sloping curve, with most drop-off locations having relatively short mean trip distances and a gradual increase toward a few locations with much longer distances. This pattern resembles the shape of a cumulative distribution function (CDF), suggesting a natural spread of values where short and medium-distance trips are most common, and longer trips are less frequent but present.

# %%
plt.figure(figsize=(16, 6)) 
sns.barplot(
    data=mean_distance_by_dropoff,
    x='DOLocationID',
    y='trip_distance',
    legend=False  
    )
plt.title('Rides by Dropoff Location ID')
plt.xlabel('Dropoff Location ID')
plt.ylabel('Mean Trip Distance (miles)')
plt.xticks([])
plt.show()

# %% [markdown]
# The bar plot shows that while most drop-off locations have short to moderate average trip distances, a few locations stand out with significantly higher mean distances. These are likely locations such as airports, outer-borough destinations, or major venues where passengers tend to travel longer distances.

# %%
plt.figure(figsize=(16, 6))

#Sort the DOLocationID column
sorted_dropoffs = taxi_data['DOLocationID'].sort_values()

sorted_dropoffs = sorted_dropoffs.astype(str)


sns.histplot(
    sorted_dropoffs,
    bins=range(0, taxi_data['DOLocationID'].max() + 1, 1)
)

# Formatting
plt.xticks([])  
plt.xlabel('Drop-off locations')
plt.ylabel('Count')
plt.title('Histogram of rides by drop-off location', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# This histogram shows the distribution of total ride counts across all drop-off locations. While most drop-off locations have relatively few rides, a few stand out with significantly higher counts, suggesting popular destinations like airports, train stations, or tourist areas. The distribution is highly skewed, with a long tail of locations that are rarely used.
